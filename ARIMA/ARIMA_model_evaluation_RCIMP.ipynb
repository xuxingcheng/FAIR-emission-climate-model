# %%
import matplotlib.pyplot as pl
import numpy as np
import pandas as pd
import xarray as xr
import math
import pickle
import os


from fair import FAIR
from fair.interface import fill, initialise
from fair.io import read_properties
from pygments.lexers.textfmts import TodotxtLexer

import statsmodels.api as sm
import pmdarima as pm

# %%
with open("/glade/work/stevenxu/FAIR_models/origional_model.pkl", "rb") as f_in:
    f1 = pickle.load(f_in)

with open("/glade/work/stevenxu/FAIR_models/top12_model.pkl", "rb") as f_in:
    f2 = pickle.load(f_in)

with open("/glade/work/stevenxu/FAIR_models/top20_model.pkl", "rb") as f_in:
    f3 = pickle.load(f_in)

with open("/glade/work/stevenxu/FAIR_models/arima_list.pkl", "rb") as f:
    arima_list = pickle.load(f)

# %%
startyear = 2017
endyear = 2300
specie = 'CO2'
da2 = f1.forcing.sel(specie=specie).mean(dim="config")
#da2.plot.line()
da2.plot.line(x="timebounds")
# Out:
# [<matplotlib.lines.Line2D at 0x7fac765e0f50>,
#  <matplotlib.lines.Line2D at 0x7fac76647b10>,
#  <matplotlib.lines.Line2D at 0x7fac76647d50>,
#  <matplotlib.lines.Line2D at 0x7fac76654190>,
#  <matplotlib.lines.Line2D at 0x7fac766544d0>,
#  <matplotlib.lines.Line2D at 0x7fac76654810>,
#  <matplotlib.lines.Line2D at 0x7fac76654cd0>,
#  <matplotlib.lines.Line2D at 0x7fac76654f50>]

# %%
startyear = 2017
endyear = 2300
specie = 'CO2'
model = arima_list[specie]

da = f1.forcing.sel(specie=specie, scenario = f1.scenarios[5], timebounds = slice(None, startyear)).mean(dim="config")
ffl_fc, ffl_conf_int = model.predict(n_periods=endyear-startyear, return_conf_int=True)


# historical data
pl.plot(da["timebounds"].values, da.values, label="Observed")

# forecast horizon (years after yrfcm = 2017)
future_years = np.arange(startyear + 1, endyear + 1)

# forecast mean
pl.plot(future_years, ffl_fc, label="Forecast", color="red")

# confidence interval
pl.fill_between(
    future_years,
    ffl_conf_int[:, 0],
    ffl_conf_int[:, 1],
    color="pink",
    alpha=0.3,
    label="95% CI"
)

pl.axvline(startyear, color="k", linestyle="--", alpha=0.5)
pl.xlabel("Year")
pl.ylabel("CH4 Forcing (W/m²)")
pl.title(f"ARIMA Forecast of {specie} Forcing ({da.scenario.values})")
pl.legend()
pl.show()

# %%
save_dir = "/glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/forcing/RCIMP"
startyear, endyear = 2017, 2100

for specie, model in arima_list.items():
    print(f"Processing {specie}...")

    # Historical data (use the same scenario index as in training)
    da = f1.forcing.sel(specie=specie, scenario=f1.scenarios[5], timebounds=slice(None, startyear)).mean(dim="config")

    # Forecast
    n_steps = endyear - startyear
    fc, ci = model.predict(n_periods=n_steps, return_conf_int=True)
    future_years = np.arange(startyear + 1, endyear + 1)

    # Plot
    pl.figure(figsize=(7, 5))
    pl.plot(da["timebounds"].values, da.values, label="Observed")
    pl.plot(future_years, fc, label="Forecast", color="red")
    pl.fill_between(future_years, ci[:, 0], ci[:, 1], alpha=0.3, color="pink", label="95% CI")
    pl.axvline(startyear, color="k", linestyle="--", alpha=0.5)
    pl.xlabel("Year")
    pl.ylabel(f"{specie} Forcing (W/m²)")
    pl.title(f"ARIMA Forecast of {specie} Forcing ({da.scenario.values})")
    pl.legend()

    # Save figure
    save_path = os.path.join(save_dir, f"{specie}_arima_forecast.png")
    pl.savefig(save_path, dpi=300, bbox_inches="tight")
    pl.close()

    print(f"Saved: {save_path}")
# Out:
# Processing CO2...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CO2_arima_forecast.png
# Processing CH4...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CH4_arima_forecast.png
# Processing N2O...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/N2O_arima_forecast.png
# Processing CFC-11...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CFC-11_arima_forecast.png
# Processing CFC-12...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CFC-12_arima_forecast.png
# Processing CFC-113...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CFC-113_arima_forecast.png
# Processing CFC-114...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CFC-114_arima_forecast.png
# Processing CFC-115...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CFC-115_arima_forecast.png
# Processing HCFC-22...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HCFC-22_arima_forecast.png
# Processing HCFC-141b...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HCFC-141b_arima_forecast.png
# Processing HCFC-142b...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HCFC-142b_arima_forecast.png
# Processing CCl4...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CCl4_arima_forecast.png
# Processing CHCl3...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CHCl3_arima_forecast.png
# Processing CH2Cl2...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CH2Cl2_arima_forecast.png
# Processing CH3Cl...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CH3Cl_arima_forecast.png
# Processing CH3CCl3...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CH3CCl3_arima_forecast.png
# Processing CH3Br...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CH3Br_arima_forecast.png
# Processing Halon-1211...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/Halon-1211_arima_forecast.png
# Processing Halon-1301...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/Halon-1301_arima_forecast.png
# Processing Halon-2402...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/Halon-2402_arima_forecast.png
# Processing CF4...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/CF4_arima_forecast.png
# Processing C2F6...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/C2F6_arima_forecast.png
# Processing C3F8...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/C3F8_arima_forecast.png
# Processing c-C4F8...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/c-C4F8_arima_forecast.png
# Processing C4F10...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/C4F10_arima_forecast.png
# Processing C5F12...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/C5F12_arima_forecast.png
# Processing C6F14...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/C6F14_arima_forecast.png
# Processing C7F16...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/C7F16_arima_forecast.png
# Processing C8F18...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/C8F18_arima_forecast.png
# Processing NF3...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/NF3_arima_forecast.png
# Processing SF6...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/SF6_arima_forecast.png
# Processing SO2F2...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/SO2F2_arima_forecast.png
# Processing HFC-125...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HFC-125_arima_forecast.png
# Processing HFC-134a...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HFC-134a_arima_forecast.png
# Processing HFC-143a...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HFC-143a_arima_forecast.png
# Processing HFC-152a...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HFC-152a_arima_forecast.png
# Processing HFC-227ea...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HFC-227ea_arima_forecast.png
# Processing HFC-23...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HFC-23_arima_forecast.png
# Processing HFC-236fa...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HFC-236fa_arima_forecast.png
# Processing HFC-245fa...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HFC-245fa_arima_forecast.png
# Processing HFC-32...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HFC-32_arima_forecast.png
# Processing HFC-365mfc...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HFC-365mfc_arima_forecast.png
# Processing HFC-4310mee...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/HFC-4310mee_arima_forecast.png
# Processing Solar...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/Solar_arima_forecast.png
# Processing Volcanic...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/Volcanic_arima_forecast.png
# Processing Aerosol-radiation interactions...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/Aerosol-radiation interactions_arima_forecast.png
# Processing Aerosol-cloud interactions...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/Aerosol-cloud interactions_arima_forecast.png
# Processing Ozone...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/Ozone_arima_forecast.png
# Processing Light absorbing particles on snow and ice...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/Light absorbing particles on snow and ice_arima_forecast.png
# Processing Stratospheric water vapour...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/Stratospheric water vapour_arima_forecast.png
# Processing Land use...
# Saved: /glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/Land use_arima_forecast.png
