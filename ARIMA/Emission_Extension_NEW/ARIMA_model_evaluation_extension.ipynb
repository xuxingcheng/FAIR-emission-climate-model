# %%
import matplotlib.pyplot as pl
import numpy as np
import pandas as pd
import xarray as xr
import math
import pickle
import os


from fair import FAIR
from fair.interface import fill, initialise
from fair.io import read_properties
from pygments.lexers.textfmts import TodotxtLexer

import statsmodels.api as sm
import pmdarima as pm

# %%
with open("/glade/work/stevenxu/FAIR_models/origional_model_extension.pkl", "rb") as f_in:
    f1 = pickle.load(f_in)

#with open("/glade/work/stevenxu/FAIR_models/top12_model_extension.pkl", "rb") as f_in:
    #f2 = pickle.load(f_in)

#with open("/glade/work/stevenxu/FAIR_models/top20_model_extension.pkl", "rb") as f_in:
    #f3 = pickle.load(f_in)

# %% [markdown]
# # Forcing

# %%
with open("/glade/work/stevenxu/FAIR_models/arima_list_forcing_extension.pkl", "rb") as f:
    arima_list = pickle.load(f)

# %%
startyear = 2024
endyear = 2300
specie = 'CO2'
model = arima_list[specie]

da = f1.forcing.sel(specie=specie, scenario = f1.scenarios[5], timebounds = slice(None, startyear)).mean(dim="config")
ffl_fc, ffl_conf_int = model.predict(n_periods=endyear-startyear, return_conf_int=True)


# historical data
pl.plot(da["timebounds"].values, da.values, label="Observed")

# forecast horizon (years after yrfcm = 2024)
future_years = np.arange(startyear + 1, endyear + 1)

# forecast mean
pl.plot(future_years, ffl_fc, label="Forecast", color="red")

# confidence interval
pl.fill_between(
    future_years,
    ffl_conf_int[:, 0],
    ffl_conf_int[:, 1],
    color="pink",
    alpha=0.3,
    label="95% CI"
)

pl.axvline(startyear, color="k", linestyle="--", alpha=0.5)
pl.xlabel("Year")
pl.ylabel("CH4 Forcing (W/m²)")
pl.title(f"ARIMA Forecast of {specie} Forcing ({da.scenario.values})")
pl.legend()
pl.show()

# %%
save_dir = "/glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/forcing/extension"

for specie, model in arima_list.items():
	print(f"start plotting {specie}")
	startyear = 2024
	endyear   = 2300
	scenario_for_forecast = f1.scenarios[5]

	fig, ax = pl.subplots(figsize=(8,5))

	# historical
	da_hist = (
		f1.forcing
		.sel(specie=specie, scenario=scenario_for_forecast, timebounds=slice(None, startyear))
		.mean(dim="config")
	)
	ax.plot(da_hist["timebounds"].values, da_hist.values,
			linewidth=2.5, color="k", label=f"historical")

	#prediction
	model = arima_list[specie]
	n_steps = endyear - startyear
	ffl_fc, ffl_conf_int = model.predict(n_periods=n_steps, return_conf_int=True)
	future_years = np.arange(startyear + 1, endyear + 1)
	ax.plot(future_years, ffl_fc, linewidth=2, color="black", linestyle="--", label="ARIMA forecast")

	# CI interval
	ax.fill_between(future_years, ffl_conf_int[:,0], ffl_conf_int[:,1],
					alpha=0.2, label="95% CI")

	# plot scenarios
	for scen in f1.scenarios:
		da_all = (
			f1.forcing
			.sel(specie=specie, scenario=scen, timebounds=slice(startyear, endyear))
			.mean(dim="config")
		)
		ax.plot(da_all["timebounds"].values, da_all.values, label=str(scen))

	# views
	ax.axvline(startyear, color="k", linestyle=":", alpha=0.6)
	ax.set_xlabel("Year")
	ax.set_ylabel("Forcing (W/m^2)")
	ax.set_title(f"ARIMA Forecast of {specie} Forcing")
	ax.legend(loc="best", ncol=1, frameon=True)
	#pl.show()

	save_path = os.path.join(save_dir, f"{specie}_arima_forecast.png")
	pl.savefig(save_path, dpi=300, bbox_inches="tight")
	pl.close()
# Out:
# start plotting CO2
# start plotting CH4
# start plotting N2O
# start plotting CFC-11
# start plotting CFC-12
# start plotting CFC-113
# start plotting CFC-114
# start plotting CFC-115
# start plotting HCFC-22
# start plotting HCFC-141b
# start plotting HCFC-142b
# start plotting CCl4
# start plotting CHCl3
# start plotting CH2Cl2
# start plotting CH3Cl
# start plotting CH3CCl3
# start plotting CH3Br
# start plotting Halon-1211
# start plotting Halon-1301
# start plotting Halon-2402
# start plotting CF4
# start plotting C2F6
# start plotting C3F8
# start plotting c-C4F8
# start plotting C4F10
# start plotting C5F12
# start plotting C6F14
# start plotting C7F16
# start plotting C8F18
# start plotting NF3
# start plotting SF6
# start plotting SO2F2
# start plotting HFC-125
# start plotting HFC-134a
# start plotting HFC-143a
# start plotting HFC-152a
# start plotting HFC-227ea
# start plotting HFC-23
# start plotting HFC-236fa
# start plotting HFC-245fa
# start plotting HFC-32
# start plotting HFC-365mfc
# start plotting HFC-4310mee
# start plotting Solar
# start plotting Volcanic
# start plotting Aerosol-radiation interactions
# start plotting Aerosol-cloud interactions
# start plotting Ozone
# start plotting Light absorbing particles on snow and ice
# start plotting Stratospheric water vapour
# start plotting Land use

# %% [markdown]
# # Emission

# %%
with open("/glade/work/stevenxu/FAIR_models/arima_list_emission_extension2.pkl", "rb") as f:
    arima_list = pickle.load(f)

# %%
arima_list.pop('Sulfur')
# Out:
# ARIMA(order=(1, 1, 3), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
print("Fitted ARIMA Orders per Species:")
print("-" * 35)

for specie, model in arima_list.items():
    # model.order returns the (p, d, q) tuple automatically
    p, d, q = model.order
    print(f"Species: {specie:<15} | Order: (p={p}, d={d}, q={q})")
# Out:
# Fitted ARIMA Orders per Species:
# -----------------------------------
# Species: CO2 FFI         | Order: (p=0, d=2, q=1)
# Species: CO2 AFOLU       | Order: (p=1, d=1, q=0)
# Species: CO2             | Order: (p=0, d=2, q=2)
# Species: CH4             | Order: (p=3, d=2, q=1)
# Species: N2O             | Order: (p=0, d=2, q=1)
# Species: BC              | Order: (p=2, d=1, q=2)
# Species: OC              | Order: (p=0, d=1, q=1)
# Species: NH3             | Order: (p=4, d=2, q=3)
# Species: NOx             | Order: (p=2, d=2, q=1)
# Species: VOC             | Order: (p=2, d=1, q=1)
# Species: CO              | Order: (p=2, d=1, q=1)
# Species: CFC-11          | Order: (p=2, d=1, q=0)
# Species: CFC-12          | Order: (p=1, d=1, q=2)
# Species: CFC-113         | Order: (p=2, d=1, q=3)
# Species: CFC-114         | Order: (p=5, d=1, q=0)
# Species: CFC-115         | Order: (p=1, d=1, q=1)
# Species: HCFC-22         | Order: (p=4, d=2, q=2)
# Species: HCFC-141b       | Order: (p=5, d=1, q=2)
# Species: HCFC-142b       | Order: (p=0, d=1, q=1)
# Species: CCl4            | Order: (p=3, d=1, q=5)
# Species: CHCl3           | Order: (p=5, d=1, q=0)
# Species: CH2Cl2          | Order: (p=2, d=2, q=1)
# Species: CH3Cl           | Order: (p=0, d=1, q=1)
# Species: CH3CCl3         | Order: (p=1, d=1, q=1)
# Species: CH3Br           | Order: (p=1, d=1, q=5)
# Species: Halon-1211      | Order: (p=4, d=1, q=1)
# Species: Halon-1301      | Order: (p=1, d=1, q=0)
# Species: Halon-2402      | Order: (p=0, d=1, q=2)
# Species: CF4             | Order: (p=2, d=1, q=5)
# Species: C2F6            | Order: (p=1, d=1, q=1)
# Species: C3F8            | Order: (p=4, d=1, q=4)
# Species: C4F10           | Order: (p=0, d=1, q=3)
# Species: C5F12           | Order: (p=3, d=1, q=0)
# Species: C6F14           | Order: (p=5, d=1, q=0)
# Species: C7F16           | Order: (p=1, d=1, q=0)
# Species: C8F18           | Order: (p=1, d=1, q=1)
# Species: NF3             | Order: (p=0, d=1, q=0)
# Species: SF6             | Order: (p=1, d=2, q=1)
# Species: SO2F2           | Order: (p=0, d=2, q=0)
# Species: HFC-125         | Order: (p=2, d=2, q=0)
# Species: HFC-134a        | Order: (p=2, d=2, q=1)
# Species: HFC-143a        | Order: (p=0, d=2, q=1)
# Species: HFC-152a        | Order: (p=4, d=1, q=2)
# Species: HFC-227ea       | Order: (p=0, d=2, q=1)
# Species: HFC-23          | Order: (p=3, d=1, q=0)
# Species: HFC-236fa       | Order: (p=3, d=2, q=4)
# Species: HFC-245fa       | Order: (p=3, d=2, q=5)
# Species: HFC-32          | Order: (p=5, d=1, q=1)
# Species: HFC-365mfc      | Order: (p=2, d=2, q=2)
# Species: HFC-4310mee     | Order: (p=1, d=1, q=2)

# %%
specie = 'CO2'
f1.emissions.sel(specie = specie).mean(dim = 'config').plot(hue = 'scenario')
# Out:
# [<matplotlib.lines.Line2D at 0x7fe52e9d7310>,
#  <matplotlib.lines.Line2D at 0x7fe52e9fa350>,
#  <matplotlib.lines.Line2D at 0x7fe52ea2a5d0>,
#  <matplotlib.lines.Line2D at 0x7fe52e9c7ed0>,
#  <matplotlib.lines.Line2D at 0x7fe52ea2aa90>,
#  <matplotlib.lines.Line2D at 0x7fe52ea2acd0>,
#  <matplotlib.lines.Line2D at 0x7fe52e9bb010>]

# %%
save_dir = "/glade/u/home/stevenxu/FAIRproject/graph_outputs/arima_plots/emission/extension"

for specie, model in arima_list.items():
	print(f"start plotting {specie}")
	startyear = 2023
	endyear   = 2100
	scenario_for_forecast = f1.scenarios[5]

	fig, ax = pl.subplots(figsize=(8,5))

	# historical
	da_hist = (
		f1.emissions
		.sel(specie=specie, scenario=scenario_for_forecast, timepoints=slice(None, startyear))
		.mean(dim="config")
	)
	ax.plot(da_hist["timepoints"].values, da_hist.values,
			linewidth=2.5, color="k", label=f"historical")

	#prediction
	model = arima_list[specie]
	n_steps = endyear - startyear
	ffl_fc, ffl_conf_int = model.predict(n_periods=n_steps, return_conf_int=True)
	future_years = np.arange(startyear + 1, endyear + 1)
	ax.plot(future_years, ffl_fc, linewidth=2, color="black", linestyle="--", label="ARIMA forecast")

	# CI interval
	ax.fill_between(future_years, ffl_conf_int[:,0], ffl_conf_int[:,1],
					alpha=0.2, label="95% CI")

	# plot scenarios
	for scen in f1.scenarios:
		da_all = (
			f1.emissions
			.sel(specie=specie, scenario=scen, timepoints=slice(startyear, endyear))
			.mean(dim="config")
		)
		ax.plot(da_all["timepoints"].values, da_all.values, label=str(scen))

	# views
	ax.axvline(startyear, color="k", linestyle=":", alpha=0.6)
	ax.set_xlabel("Year")
	ax.set_ylabel("Emission (Mt/yr)")
	ax.set_title(f"ARIMA Forecast of {specie} Emission")
	ax.legend(loc="best", ncol=1, frameon=True)
	#pl.show()

	save_path = os.path.join(save_dir, f"{specie}_arima_forecast.png")
	pl.savefig(save_path, dpi=300, bbox_inches="tight")
	pl.close()
# Out:
# start plotting CO2 FFI
# start plotting CO2 AFOLU
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting CO2
# start plotting CH4
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting N2O
# start plotting BC
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting OC
# start plotting NH3
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting NOx
# start plotting VOC
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting CO
# start plotting CFC-11
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting CFC-12
# start plotting CFC-113
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting CFC-114
# start plotting CFC-115
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting HCFC-22
# start plotting HCFC-141b
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting HCFC-142b
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting CCl4
# start plotting CHCl3
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting CH2Cl2
# start plotting CH3Cl
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting CH3CCl3
# start plotting CH3Br
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting Halon-1211
# start plotting Halon-1301
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting Halon-2402
# start plotting CF4
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting C2F6
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting C3F8
# start plotting C4F10
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting C5F12
# start plotting C6F14
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting C7F16
# start plotting C8F18
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting NF3
# start plotting SF6
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting SO2F2
# start plotting HFC-125
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting HFC-134a
# start plotting HFC-143a
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting HFC-152a
# start plotting HFC-227ea
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting HFC-23
# start plotting HFC-236fa
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting HFC-245fa
# start plotting HFC-32
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# start plotting HFC-365mfc
# start plotting HFC-4310mee
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /glade/work/stevenxu/conda-envs/amoc-env/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
